# %%
from datasets import load_dataset

dataset = load_dataset("JoshuaW1997/FUTGA", "MusicCaps", split="train")
print(dataset)
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# README.md:   0%|          | 0.00/908 [00:00<?, ?B/s]
# MusicCaps.csv: 0.00B [00:00, ?B/s]
# Generating train split:   0%|          | 0/5397 [00:00<?, ? examples/s]
# Dataset({
#     features: ['index', 'caption'],
#     num_rows: 5397
# })

# %%
for i in range(3):
    print(dataset[i]["caption"])
# Out:
# The music is energetic, youthful, enthusiastic, high-powered, energetic, psychedelic, dance groove with a strong electronic dance music (EDM) influence. The overall mood is upbeat and optimistic. The theme is one of youth, energy, and freedom. The tempo is fast, ranging from 120 BPM to 160 BPM. The melody is catchy and memorable, with a strong emphasis on synthesizers and drum machines. The chord progression is typically EDM-style, with a focus on syncopated chords and chromaticism.
#
# **Functional Segment Descriptions:**
#
# **0-20% - Intro/Verse:**
# - Introduction of the electronic drum machine and synthesizer.
# - Slow build-up of the tempo and melody.
# - Establishment of the main theme and chord progression.
#
# **20-41% - Chorus:**
# - Increase in tempo and intensity.
# - Repetition of the main melody and chord progression.
# - Addition of vocal elements.
#
# **41-63% - Bridge:**
# - Change in tempo and mood.
# - Introduction of new melodies and chord progressions.
# - Build-up to the climax.
#
# **63-81% - Verse:**
# - Repetition of the main melody and chord progression.
# - Addition of new vocal elements.
#
# **81-100% - Outro:**
# - Decrease in tempo and intensity.
# - Fade out of the main melody and chord progression.
# - Conclusion of the song.
# The music is characterized by its energetic and uplifting mood, catchy melody, and simple yet effective chord progression. The overall theme is one of joy and happiness, conveyed through the use of bright and cheerful instruments such as bells, xylophone, and acoustic guitar.
#
# **Functional Segments:**
#
# **0-16% - Intro/Melody:**
# - Introduction of the main melody played on the xylophone, accompanied by a rhythmic pattern created by the percussion instruments.
# - The melody is simple and memorable, with a strong focus on the tonic and dominant chords.
#
# **16-38% - Verse/Chorus:**
# - Male voice joins the melody, singing along with the main melody.
# - The bass plays the root notes of the chords, creating a strong foundation for the melody.
# - The chords change to a minor key, creating a sense of tension and anticipation.
#
# **38-59% - Bridge:**
# - Strings and wind instruments are added to the mix, creating a more expansive sound.
# - The melody changes to a more melancholic one, reflecting the mood of the bridge.
#
# **59-79% - Instrumental Bridge:**
# - The main melody is played on a single instrument, creating a haunting and mysterious atmosphere.
#
# **79-100% - Outro/Lullaby:**
# - A wooden percussion and xylophone are added to the mix, creating a calming and soothing atmosphere.
# - The cello plays single chords that bounce from one beat to the next.
# - The song fades out, leaving a lingering sense of tranquility.
# The song is an electronic dance music (EDM) track with a strong focus on synths and drums. The overall mood is energetic and uplifting, with a theme of youth and vitality. The tempo is fast, with a driving beat that propels the music forward. The melody is catchy and memorable, with a strong hook that is easy to remember. The chord progression is simple but effective, using a combination of major and minor chords to create a sense of tension and release.
#
# **Functional Segments:**
#
# **0-20% - Intro and Verse:**
# - Electric guitar and drums start the song with a driving beat.
# - Synths begin playing a melodic counterpoint to the drums.
# - Male vocals begin rapping.
#
# **20-40% - Chorus:**
# - Synths and drums intensify.
# - Male vocals sing the chorus, which is catchy and memorable.
#
# **40-63% - Industrial Metal:**
# - Male vocalist uses the fry scream technique.
# - Distorted electric guitar plays a heavy riff.
# - Groovy bass line and loud metal beat.
#
# **63-84% - Techno House:**
# - Piercing synth lead plays an alarm-like tune.
# - Loud and aggressive atmosphere.
#
# **84-100% - Country Hard Rock:**
# - Pedal steel guitar plays sliding notes.
# - Acoustic guitar strums chords in the background.
# - Bass guitar plays the root notes of the chords.
# - No voices.

# %%
import numpy as np
X = np.load("data/processed/features.npy")
print("Feature shape:", X.shape)
